# %% [markdown]
# ### Hi welcome back I am using this notebook for performing the below Experiment
# ## Generate embeddings for 5 sentences, print their shape

# %%
from sentence_transformers import SentenceTransformer

# %%
model = SentenceTransformer("all-MiniLM-L6-v2")
# Out:
# Loading weights: 100%|██████████| 103/103 [00:00<00:00, 17241.22it/s]

# %%
sentences = [
    "The cat sat on the mat.",
    "A dog ran across the field.",
    "Machine learning is fun.",
    "Deep learning builds on ML.",
    "Paris is the capital of France."
]

# %%
embeddings = model.encode(sentences)
print(embeddings.shape)   # expect (5, 384)
print(type(embeddings))   # numpy array
# Out:
# (5, 384)
# <class 'numpy.ndarray'>
