# %% [markdown]
# ### In this notebook i am trying to Create a ChromaDB collection, add 50 documents with metadata

# %% [markdown]
# ### Step 1. Create a collection + add 50 documents with metadata

# %%
import chromadb
from chromadb.utils import embedding_functions

# %%
client = chromadb.PersistentClient(path="./chroma_db50")

# %%
embed_fn = embedding_functions.SentenceTransformerEmbeddingFunction(
    model_name="all-MiniLM-L6-v2"
)

# %%
collection = client.get_or_create_collection(
    name="daily_docs",
    embedding_function=embed_fn
)

# %%
documents = [
    "Employees are entitled to 20 days of paid annual leave each calendar year.",
    "Employees may carry forward up to 5 unused vacation days into the next year.",
    "Sick leave can be taken for illness or medical appointments with manager approval.",
    "The company provides health insurance for employees and their eligible dependents.",
    "Dental and vision insurance are included in the employee benefits package.",
    "Employees may work remotely up to three days per week with manager approval.",
    "Remote employees must attend all mandatory virtual meetings during business hours.",
    "Office working hours are from 9:00 AM to 6:00 PM, Monday through Friday.",
    "Overtime must be approved in advance by the employee's department manager.",
    "Employees receive their salary on the last working day of each month.",
    "Performance reviews are conducted twice every year to evaluate employee progress.",
    "Outstanding performance may be rewarded with annual bonuses and promotions.",
    "All employees must complete cybersecurity awareness training every six months.",
    "Passwords should be changed every 90 days and must not be shared.",
    "Confidential company information must never be shared with unauthorized individuals.",
    "Business travel expenses must be submitted within 30 days for reimbursement.",
    "Employees are eligible for domestic and international travel allowances.",
    "New employees must complete onboarding within their first two weeks.",
    "Managers are responsible for approving employee leave requests.",
    "Employees must report workplace harassment to the Human Resources department.",
    "Employees should notify their manager at least two weeks before taking planned leave.",
    "Parental leave is available for eligible employees according to company policy.",
    "Bereavement leave may be granted following the loss of an immediate family member.",
    "Employees are expected to maintain professional conduct while representing the company.",
    "The dress code is business casual unless otherwise specified by the department.",
    "Company laptops must be used only for authorized business purposes.",
    "Personal devices used for work must have updated antivirus software installed.",
    "Employees should lock their computers before leaving their desks.",
    "Customer data must be handled according to privacy and data protection regulations.",
    "All software installations require approval from the IT department.",
    "Training sessions are available for leadership, communication, and technical skills.",
    "Employees are encouraged to complete at least one professional development course each year.",
    "Conference attendance may be sponsored based on business requirements.",
    "Managers should provide constructive feedback during one-on-one meetings.",
    "Expense reports must include receipts for all business-related purchases.",
    "Meals during approved business travel are reimbursable within policy limits.",
    "Employees should immediately report lost or stolen company equipment.",
    "Visitors must sign in at the reception desk before entering office premises.",
    "Emergency exits should remain unobstructed at all times.",
    "Fire drills are conducted twice a year to ensure workplace safety.",
    "Smoking is prohibited inside all company buildings.",
    "Parking spaces are allocated on a first-come, first-served basis.",
    "Employees can reserve meeting rooms through the internal booking system.",
    "Project documentation should be stored in the company's approved document repository.",
    "Teams should conduct retrospective meetings after completing major projects.",
    "Code reviews are mandatory before merging changes into the main branch.",
    "Critical production incidents must be reported to the on-call engineering team immediately.",
    "All customer support requests should receive an initial response within four business hours.",
    "Employees are encouraged to share innovative ideas through the company innovation portal.",
    "Exit interviews help the company improve employee experience and workplace policies."
]

metadatas = [
    {"category": "leave", "doc_id": 1},
    {"category": "leave", "doc_id": 2},
    {"category": "leave", "doc_id": 3},
    {"category": "benefits", "doc_id": 4},
    {"category": "benefits", "doc_id": 5},
    {"category": "remote_work", "doc_id": 6},
    {"category": "remote_work", "doc_id": 7},
    {"category": "work_hours", "doc_id": 8},
    {"category": "payroll", "doc_id": 9},
    {"category": "payroll", "doc_id": 10},
    {"category": "performance", "doc_id": 11},
    {"category": "performance", "doc_id": 12},
    {"category": "security", "doc_id": 13},
    {"category": "security", "doc_id": 14},
    {"category": "security", "doc_id": 15},
    {"category": "travel", "doc_id": 16},
    {"category": "travel", "doc_id": 17},
    {"category": "onboarding", "doc_id": 18},
    {"category": "management", "doc_id": 19},
    {"category": "hr", "doc_id": 20},
    {"category": "leave", "doc_id": 21},
    {"category": "leave", "doc_id": 22},
    {"category": "leave", "doc_id": 23},
    {"category": "conduct", "doc_id": 24},
    {"category": "conduct", "doc_id": 25},
    {"category": "security", "doc_id": 26},
    {"category": "security", "doc_id": 27},
    {"category": "security", "doc_id": 28},
    {"category": "security", "doc_id": 29},
    {"category": "it", "doc_id": 30},
    {"category": "training", "doc_id": 31},
    {"category": "training", "doc_id": 32},
    {"category": "training", "doc_id": 33},
    {"category": "management", "doc_id": 34},
    {"category": "finance", "doc_id": 35},
    {"category": "travel", "doc_id": 36},
    {"category": "it", "doc_id": 37},
    {"category": "security", "doc_id": 38},
    {"category": "safety", "doc_id": 39},
    {"category": "safety", "doc_id": 40},
    {"category": "safety", "doc_id": 41},
    {"category": "facilities", "doc_id": 42},
    {"category": "facilities", "doc_id": 43},
    {"category": "documentation", "doc_id": 44},
    {"category": "project_management", "doc_id": 45},
    {"category": "engineering", "doc_id": 46},
    {"category": "engineering", "doc_id": 47},
    {"category": "customer_support", "doc_id": 48},
    {"category": "innovation", "doc_id": 49},
    {"category": "hr", "doc_id": 50},
]


ids = [f"doc_{i}" for i in range(1, 51)]

# %%
collection.add(
    documents=documents,
    metadatas=metadatas,
    ids = ids
)

# %%
print("collection Count: ", collection.count())
# Out:
# collection Count:  50

# %% [markdown]
# ### Step 2. Run your first similarity query — top 5

# %%
results = collection.query(
    query_texts=["Sample Document about Company Policies"],
    n_results=5,
    include=["metadatas", "documents", "distances"],
)

documents = results.get("documents") or []
metadatas = results.get("metadatas") or []
distances = results.get("distances") or []

if not documents or not metadatas or not distances:
    print("No results found.")
else:
    for doc, meta, dist in zip(documents[0], metadatas[0], distances[0]):
        print(f"Score: {dist:.4f} | Meta: {meta} | Text: {doc[:80]}")
# Out:
# Score: 0.5795 | Meta: {'category': 'documentation', 'doc_id': 44} | Text: Project documentation should be stored in the company's approved document reposi
# Score: 0.5837 | Meta: {'category': 'benefits', 'doc_id': 4} | Text: The company provides health insurance for employees and their eligible dependent
# Score: 0.6505 | Meta: {'category': 'conduct', 'doc_id': 24} | Text: Employees are expected to maintain professional conduct while representing the c
# Score: 0.6564 | Meta: {'doc_id': 5, 'category': 'benefits'} | Text: Dental and vision insurance are included in the employee benefits package.
# Score: 0.6714 | Meta: {'doc_id': 19, 'category': 'management'} | Text: Managers are responsible for approving employee leave requests.
