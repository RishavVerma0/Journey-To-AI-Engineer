# %% [markdown]
# ### Daily dataset index — load Wikipedia intro paragraphs

# %%
import wikipedia
import chromadb
def fetch_intro(title):
    try:
        return wikipedia.summary(title, sentences=3)
    except Exception as e:
        print(f"Skipped {title}: {e}")
        return None

topics = [
    "Python (programming language)", "Machine learning", "Artificial intelligence",
    "ChromaDB", "Natural language processing", "Data science",
    # ... add as many as you want, or pull a random/trending list daily
]

wiki_docs, wiki_ids, wiki_metas = [], [], []
for i, topic in enumerate(topics):
    intro = fetch_intro(topic)
    if intro:
        wiki_docs.append(intro)
        wiki_ids.append(f"wiki_{i}")
        wiki_metas.append({"project": "daily_dataset_index", "title": topic, "source": "wikipedia"})

# Create a persistent client
cclient = chromadb.PersistentClient(path="./chroma_db")

collection = client.get_or_create_collection("wikipedia_docs")

collection.add(
    documents=wiki_docs,
    metadatas=wiki_metas,
    ids=wiki_ids
)

print(f"Added {len(wiki_docs)} Wikipedia intros")
# Out:
# Skipped Machine learning: Page id "machine ;earning" does not match any pages. Try another id!
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/wikipedia/wikipedia.py:389: GuessedAtParserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("html.parser"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 389 of the file /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/wikipedia/wikipedia.py. To get rid of this warning, pass the additional argument 'features="html.parser"' to the BeautifulSoup constructor.
#
#   lis = BeautifulSoup(html).find_all('li')
# Skipped ChromaDB: "chroma" may refer to:
# Chroma (video)
# colorfulness
# Munsell color system
# Chroma (vector database)
# Chroma key
# ...
