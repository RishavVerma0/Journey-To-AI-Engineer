# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from dataclasses import dataclass

@dataclass
class ColourContext:
    favourite_colour: str = "blue"
    leaset_favourite_colour: str = "yellow"

# %%
from langchain.agents import create_agent

agent = create_agent(
    model="ollama:qwen2.5:3b",
    context_schema=ColourContext
)

# %%
from langchain.messages import HumanMessage

response = agent.invoke(
    {"messages": [HumanMessage(content="What is my favourite colour?")]},
    context=ColourContext()
)

# %%
from pprint import pprint

pprint(response)
# Out:
# {'messages': [HumanMessage(content='What is my favourite colour?', additional_kwargs={}, response_metadata={}, id='36c14913-b059-43a7-b9db-a756d790056c'),
#               AIMessage(content="My knowledge doesn't have information about your personal preferences or characteristics since I don't have access to any data specific to you. To find out what your favorite color is, you can recall it yourself, ask someone who knows you well, or perhaps share this with me if you're comfortable doing so in a private context.", additional_kwargs={}, response_metadata={'model': 'qwen2.5:3b', 'created_at': '2026-07-14T17:50:27.815794Z', 'done': True, 'done_reason': 'stop', 'total_duration': 3241091333, 'load_duration': 169001750, 'prompt_eval_count': 35, 'prompt_eval_duration': 55419000, 'eval_count': 65, 'eval_duration': 2981866000, 'logprobs': None, 'model_name': 'qwen2.5:3b', 'model_provider': 'ollama'}, id='lc_run--019f61c0-5d24-7c00-8552-947a7f3bd895-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 35, 'output_tokens': 65, 'total_tokens': 100})]}

# %% [markdown]
# # Accessing Context

# %%
from langchain.tools import tool, ToolRuntime

@tool
def get_favourite_colour(runtime: ToolRuntime) -> str:
    """Get the favourite colour of the user"""
    return runtime.context.favourite_colour

@tool
def get_least_favourite_colour(runtime: ToolRuntime) -> str:
    """Get the least favourite colour of the user"""
    return runtime.context.least_favourite_colour

# %%
agent = create_agent(
    model="ollama:qwen2.5:3b",
    tools=[get_favourite_colour, get_least_favourite_colour],
    context_schema=ColourContext
)

# %%
response = agent.invoke(
    {"messages": [HumanMessage(content="What is my favourite colour?")]},
    context=ColourContext()
)

pprint(response)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pydantic/functional_validators.py:835: UserWarning: Pydantic serializer warnings:
#   PydanticSerializationUnexpectedValue(Expected `none` - serialized value may not be as expected [field_name='context', input_value=ColourContext(favourite_c...vourite_colour='yellow'), input_type=ColourContext])
#   function=lambda v, h: h(v), schema=original_schema
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pydantic/main.py:475: UserWarning: Pydantic serializer warnings:
#   PydanticSerializationUnexpectedValue(Expected `none` - serialized value may not be as expected [field_name='context', input_value=ColourContext(favourite_c...vourite_colour='yellow'), input_type=ColourContext])
#   return self.__pydantic_serializer__.to_python(
# {'messages': [HumanMessage(content='What is my favourite colour?', additional_kwargs={}, response_metadata={}, id='27712bf8-5320-4551-9592-22b295c2ae79'),
#               AIMessage(content='', additional_kwargs={}, response_metadata={'model': 'qwen2.5:3b', 'created_at': '2026-07-14T17:50:29.023296Z', 'done': True, 'done_reason': 'stop', 'total_duration': 1040006208, 'load_duration': 149460291, 'prompt_eval_count': 180, 'prompt_eval_duration': 49125000, 'eval_count': 18, 'eval_duration': 825394000, 'logprobs': None, 'model_name': 'qwen2.5:3b', 'model_provider': 'ollama'}, id='lc_run--019f61c0-6a8c-7df1-ac17-57d01c2dbc48-0', tool_calls=[{'name': 'get_favourite_colour', 'args': {}, 'id': 'd48ce805-7664-4836-a80d-2641328d383c', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 180, 'output_tokens': 18, 'total_tokens': 198}),
#               ToolMessage(content='blue', name='get_favourite_colour', id='eccdf08e-530d-4c42-9e7d-c182f8315e89', tool_call_id='d48ce805-7664-4836-a80d-2641328d383c'),
#               AIMessage(content='Your favourite color is blue.', additional_kwargs={}, response_metadata={'model': 'qwen2.5:3b', 'created_at': '2026-07-14T17:50:29.649671Z', 'done': True, 'done_reason': 'stop', 'total_duration': 610129333, 'load_duration': 159979000, 'prompt_eval_count': 217, 'prompt_eval_duration': 165263000, 'eval_count': 7, 'eval_duration': 279262000, 'logprobs': None, 'model_name': 'qwen2.5:3b', 'model_provider': 'ollama'}, id='lc_run--019f61c0-6eae-7423-93f1-3543470afacd-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 217, 'output_tokens': 7, 'total_tokens': 224})]}

# %%
response = agent.invoke(
    {"messages": [HumanMessage(content="What is my favourite colour?")]},
    context=ColourContext(favourite_colour="green")
)

pprint(response)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pydantic/functional_validators.py:835: UserWarning: Pydantic serializer warnings:
#   PydanticSerializationUnexpectedValue(Expected `none` - serialized value may not be as expected [field_name='context', input_value=ColourContext(favourite_c...vourite_colour='yellow'), input_type=ColourContext])
#   function=lambda v, h: h(v), schema=original_schema
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pydantic/main.py:475: UserWarning: Pydantic serializer warnings:
#   PydanticSerializationUnexpectedValue(Expected `none` - serialized value may not be as expected [field_name='context', input_value=ColourContext(favourite_c...vourite_colour='yellow'), input_type=ColourContext])
#   return self.__pydantic_serializer__.to_python(
# {'messages': [HumanMessage(content='What is my favourite colour?', additional_kwargs={}, response_metadata={}, id='a021e500-e79f-432c-b096-e16c4abd2795'),
#               AIMessage(content='', additional_kwargs={}, response_metadata={'model': 'qwen2.5:3b', 'created_at': '2026-07-14T17:50:30.772264Z', 'done': True, 'done_reason': 'stop', 'total_duration': 1110230250, 'load_duration': 137534667, 'prompt_eval_count': 180, 'prompt_eval_duration': 42459000, 'eval_count': 22, 'eval_duration': 924988000, 'logprobs': None, 'model_name': 'qwen2.5:3b', 'model_provider': 'ollama'}, id='lc_run--019f61c0-711d-7921-97c9-760f57e6b2b8-0', tool_calls=[{'name': 'get_favourite_colour', 'args': {'user_id': None}, 'id': '0b7848c8-6555-45d3-8d8f-0fbc4e53f79f', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 180, 'output_tokens': 22, 'total_tokens': 202}),
#               ToolMessage(content='green', name='get_favourite_colour', id='f8940744-7076-4e85-8cb6-bf102155df79', tool_call_id='0b7848c8-6555-45d3-8d8f-0fbc4e53f79f'),
#               AIMessage(content='Your favourite colour is green.', additional_kwargs={}, response_metadata={'model': 'qwen2.5:3b', 'created_at': '2026-07-14T17:50:31.365477Z', 'done': True, 'done_reason': 'stop', 'total_duration': 578467125, 'load_duration': 138447917, 'prompt_eval_count': 221, 'prompt_eval_duration': 162564000, 'eval_count': 7, 'eval_duration': 274100000, 'logprobs': None, 'model_name': 'qwen2.5:3b', 'model_provider': 'ollama'}, id='lc_run--019f61c0-7582-7f42-8356-89bd8ae9ab2b-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 221, 'output_tokens': 7, 'total_tokens': 228})]}

# %%
print(response["messages"][-1].content)
# Out:
# Your favourite colour is green.
