# %% [markdown]
# # Tool Definition

# %%
from langchain.tools import tool

@tool
def square_root(x: float) -> float:
    """Calculate the square root of a number"""
    return x ** 0.5

# %%
@tool("square_root")
def tool1(x: float) -> float:
    """Calculate the square root of a number"""
    return x ** 0.5

# %%
@tool("square_root", description="Calculate the square root of a number")
def tool1(x: float) -> float:
    return x ** 0.5

# %%
tool1.invoke({"x":467})
# Out:
# 21.61018278497431

# %% [markdown]
# # Adding to agents

# %%
from langchain.agents import create_agent

agent = create_agent(
    model="ollama:qwen2.5:3b",
    tools=[tool1],
    system_prompt="You are an arithmetic wizard. Use your tools to calculate the square root and square of any number."
)

# %%
from langchain.messages import HumanMessage

question = HumanMessage(content="What is the square root of 467?")


response = agent.invoke(
    {"messages": [question]}
)
print(response['messages'][-1].content)
# Out:
# The square root of 467 is approximately 21.610.

# %%
from pprint import pprint

pprint(response['messages'])
# Out:
# [HumanMessage(content='What is the square root of 467?', additional_kwargs={}, response_metadata={}, id='c254345d-22e5-48ac-842e-f1f38322d225'),
#  AIMessage(content='', additional_kwargs={}, response_metadata={'model': 'qwen2.5:3b', 'created_at': '2026-07-12T17:05:25.421902Z', 'done': True, 'done_reason': 'stop', 'total_duration': 5637650500, 'load_duration': 4079516250, 'prompt_eval_count': 160, 'prompt_eval_duration': 631521000, 'eval_count': 22, 'eval_duration': 899994000, 'logprobs': None, 'model_name': 'qwen2.5:3b', 'model_provider': 'ollama'}, id='lc_run--019f574a-5f6d-7f03-95b8-a0b6509a84ef-0', tool_calls=[{'name': 'square_root', 'args': {'x': 467}, 'id': 'a22f7022-7352-4e9d-a6b8-4904754f90ca', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 160, 'output_tokens': 22, 'total_tokens': 182}),
#  ToolMessage(content='21.61018278497431', name='square_root', id='94b418cf-22e5-44cc-b3a5-4faaea46c2c8', tool_call_id='a22f7022-7352-4e9d-a6b8-4904754f90ca'),
#  AIMessage(content='The square root of 467 is approximately 21.610.', additional_kwargs={}, response_metadata={'model': 'qwen2.5:3b', 'created_at': '2026-07-12T17:05:26.631156Z', 'done': True, 'done_reason': 'stop', 'total_duration': 1170803792, 'load_duration': 159752292, 'prompt_eval_count': 216, 'prompt_eval_duration': 265555000, 'eval_count': 19, 'eval_duration': 742874000, 'logprobs': None, 'model_name': 'qwen2.5:3b', 'model_provider': 'ollama'}, id='lc_run--019f574a-75d1-7983-97f2-50d5fab7b82b-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 216, 'output_tokens': 19, 'total_tokens': 235})]

# %%
print(response["messages"][1].tool_calls)
# Out:
# [{'name': 'square_root', 'args': {'x': 467}, 'id': '0bd329c3-ec97-4f92-ab0e-f2d5af53292c', 'type': 'tool_call'}]
