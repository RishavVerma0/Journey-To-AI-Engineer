# %% [markdown]
# # Basic Prompting

# %%
from langchain.agents import create_agent
from langchain.messages import HumanMessage

agent = create_agent(model="ollama:qwen2.5:3b")

question = HumanMessage(content="What is the capital of the moon?")

response = agent.invoke(
    {"messages": [question]}
)

print(response['messages'][1].content)
# Out:
# The Moon does not have a capital city because it is an astronomical body without any solid surface or atmosphere. It lacks features that could be considered a settlement or a capital city. The United States established the Apollo Lunar Landing sites as a symbolic gesture, but these are simply landing spots and not actual cities.

# %%
system_prompt = "You are a science fiction writer, create a capital city at the users request."

scifi_agent = create_agent(
    model="ollama:qwen2.5:3b",
    system_prompt=system_prompt
)

response = scifi_agent.invoke(
    {"messages": [question]}
)

print(response['messages'][1].content)
# Out:
# Ah, that's an interesting twist to a common urban legend or popular culture reference! The idea of having a "capital" on the Moon has been explored in various forms of media, from science fiction stories to space exploration concepts.
#
# If we were to create a plausible scenario for this hypothetical capital city on the Moon, it might look something like this:
#
# 1. **Name and Geography**: Let's name it Luna City, situated in the highlands near the Moon's northern pole. The site is chosen due to its proximity to potential resources such as Helium-3 and water ice.
#
# 2. **Geological Features**: The city would be built on an artificial plateau, possibly with a series of interconnected domes or underground chambers to protect against extreme temperatures (extreme cold at night, extreme heat during the day), micrometeorite impacts, and radiation exposure.
#
# 3. **Infrastructure**:
#    - **Transportation System**: A network of airlocks connected by tubes, allowing for quick movement between different parts of the city and with lunar rovers.
#    - **Power Generation**: Harnessing solar power through large reflective surfaces or arrays that can be adjusted to track sunlight efficiently, combined with potentially a small nuclear reactor for backup during lunar nights.
#
# 4. **Living Arrangements**:
#    - **Habitats**: Living quarters could include dome habitats built underground for year-round protection from temperature extremes and cosmic radiation.
#    - **Greenhouses**: To grow food, these would be located in areas where there is sufficient soil or hydroponic solutions can be used.
#
# 5. **Economic and Social Structure**:
#    - **Industry Focus**: Mining facilities for Helium-3 (a potential energy source) could be present along with research labs focused on lunar mining techniques.
#    - **Tourism and Education**: As an outpost, it might also serve as a base for tourism or educational missions.
#
# 6. **Technology Integration**: Advanced robotic systems would play a crucial role in the daily operations of this city, from managing resources to conducting scientific experiments.
#
# While Luna City is purely fictional at this moment, similar ideas are being considered by space agencies and private companies looking into establishing human settlements on the Moon in the future.

# %% [markdown]
# ## Few-Shot Examples

# %%
system_prompt = """

You are a science fiction writer, create a space capital city at the users request.

User: What is the capital of mars?
Scifi Writer: Marsialis

User: What is the capital of Venus?
Scifi Writer: Venusovia

"""

scifi_agent = create_agent(
    model="ollama:qwen2.5:3b",
    system_prompt=system_prompt
)

response = scifi_agent.invoke(
    {"messages": [question]}
)

print(response['messages'][1].content)
# Out:
# For the sake of creativity and a bit of whimsy, let's call the capital of the Moon Lunaopolis.
#
# This name combines elements of lunar reference with an urban flair, creating a fitting and imaginative title for this bustling metropolis on Earth’s only natural satellite.

# %% [markdown]
# ## Structured Prompts

# %%
system_prompt = """

You are a science fiction writer, create a space capital city at the users request.

Please keep to the below structure.

Name: The name of the capital city

Location: Where it is based

Vibe: 2-3 words to describe its vibe

Economy: Main industries

"""

scifi_agent = create_agent(
    model="ollama:qwen2.5:3b",
    system_prompt=system_prompt
)

response = scifi_agent.invoke(
    {"messages": [question]}
)

print(response['messages'][1].content)
# Out:
# I understand your request, but I'll need to clarify that there is no space capital city or country on Earth. However, if we were to imagine a fictional space capital city based in our solar system, let's proceed with creating one:
#
# ### Name: LunaCore City
#
# ### Location: A high orbit around the Moon, providing a constant view of its surface and lunar stations below
#
# ### Vibe: Frontier, Futuristic, Lunar Hub
#
# ### Economy: Main industries include:
# - **Space Tourism**: Visitors from Earth come to witness the unique views and explore the moon's history.
# - **Lunar Exploration Research Facilities**: Advanced labs for studying the Moon’s geology, potential resources like Helium-3, and biological experiments in microgravity conditions.
# - **Manufacturing of Space-Available Products**: Producing specialized materials that can be used on both Earth and other planets such as lunar regolith-based construction materials, solar panels, and advanced mining equipment.
#
# This fictional capital city would serve as a nexus for space exploration and development, blending cutting-edge technology with the unique environment of orbiting above the Moon.

# %% [markdown]
# ## Structured Output

# %%
from langchain.agents import create_agent
from langchain.messages import HumanMessage
from pydantic import BaseModel

class CapitalInfo(BaseModel):
    name: str
    location: str
    vibe: str
    economy: str

agent = create_agent(
    model="ollama:qwen2.5:3b",
    system_prompt="You are a science fiction writer, create a capital city at the users request.",
    response_format=CapitalInfo
)

question = HumanMessage(content="What is the capital of The Moon?")

response = agent.invoke(
    {"messages": [question]}
)

response["structured_response"]
# Out:
# CapitalInfo(name='Luna City', location='Not on surface', vibe='Futuristic, sustainable living', economy='Thriving due to mining and tourism')

# %%
response["structured_response"].name
# Out:
# 'Luna City'

# %%
capital_info = response["structured_response"]

capital_name = capital_info.name
capital_location = capital_info.location

print(f"{capital_name} is a city located at {capital_location}")
# Out:
# Luna City is a city located at Not on surface
