# %% [markdown]
# # Without Web Search

# %%
from langchain.agents import create_agent

agent = create_agent(
    model= "ollama:qwen2.5:3b"
)

# %%
from langchain.messages import HumanMessage

question = HumanMessage(content="How up to date is your training knowledge?")

response = agent.invoke(
    {"messages": [question]}
)

print(response["messages"][-1].content)
# Out:
# As of my current state, I have been trained with data and information available up until October 2021. Since then, there has not been an immediate update to my training model. New developments in technology, scientific research, news events, and other areas can continue to impact the accuracy and freshness of the knowledge contained within my database.
#
# For the most current information on specific topics or data points, it would be best to verify with authoritative sources or more recent reliable databases. I am always here to assist you with any queries related to the knowledge that is currently available in my training.

# %% [markdown]
# # Add web search tool

# %%
from langchain.tools import tool
from typing import Dict, Any
from tavily import TavilyClient
import os 
from dotenv import load_dotenv

load_dotenv()

tavily_client = TavilyClient()

@tool 
def web_search(query:str) -> Dict[str, Any]:
    """Search the web for information"""
    return tavily_client.search(query)

web_search.invoke("Who is the current CEO of Wipro?")
# Out:
# {'query': 'Who is the current CEO of Wipro?',
#  'follow_up_questions': None,
#  'answer': None,
#  'images': [],
#  'results': [{'url': 'https://www.wipro.com/newsroom/press-releases/2024/wipro-appoints-srini-pallia-as-ceo-and-managing-director',
#    'title': 'Wipro Appoints Srini Pallia as CEO & Managing Director',
#    'content': "| BENGALURU, India – April 6, 2024**:\xa0 Wipro Limited (NYSE: WIT, BSE: 507685, NSE: WIPRO), a leading technology services and consulting company, today announced the appointment of Srini Pallia as the Chief Executive Officer and Managing Director of the Company, effective immediately. Srini has been with Wipro for over three decades and most recently served as the CEO for\xa0Americas 1, Wipro's biggest and fastest growing strategic market. “Srini is an ideal leader to lead Wipro at this pivotal moment for our company and industry. Thierry Delaporte said, “I'm grateful to Rishad and the Board for the opportunity to lead Wipro through a period of significant transformation. In the four years we have worked together, Srini has built a successful business in our largest market of Americas 1 and has become an important strategic partner to our clients.",
#    'score': 0.9183121,
#    'raw_content': None},
#   {'url': 'https://www.instagram.com/p/C5bI250vFXm?hl=en',
#    'title': 'Instagram',
#    'content': "Wipro appoints Srini Pallia as CEO and Managing Director. Congratulations on your well-deserved appointment as CEO and Managing Director of Wipro, Srini Pallia! May be an image of one or more people, crowd and text that says 'wipro: 香 12061 50624 S0n 2624 E ธ7ว9 S50BO'. May be a meme of one or more people, poster and text that says 'wipro: prö:intelligence™ proofoverpromise. May be an image of phone, screen and text that says 'wipro: The future of telecom isn't coming. Photo by Wipro on July 06, 2026. May be an image of text. May be an image of one or more people, people standing, suit, screen, office and text. May be a graphic of poster, magazine and text that says 'wipro: Fixing Strategies in Life Sciences SDLC O0000'. May be an image of poster, magazine and text that says 'wipro: A System Under Strain: The New Reality of Utility Connections'.",
#    'score': 0.8958969,
#    'raw_content': None},
#   {'url': 'https://www.wipro.com/leadership/executive-leadership-team',
#    'title': 'Executive Leadership Team at Wipro Driving Business ...',
#    'content': '#### Europe ›. #### Americas ›. #### Asia & Pacific ›. Asia & Pacific Sub Menu Opened. #### India & Middle East ›. India & Middle East Sub Menu Opened. #### Africa. favorite page  unfavorite page  share icon). #### Srini Pallia. Chief Executive Officer & Managing Director. View Profile Nagendra P Bandaru. #### Nagendra P Bandaru. Managing Partner and Global Head – Technology Services. #### Suzanne Dann. #### Vinay Firake. #### Saurabh Govil. #### Aparna C. #### Sanjeev Jain. #### Malay Joshi. View Profile Jasjit Singh Kang. #### Jasjit Singh Kang. Managing Partner and Global Head – Business Process Services. #### Amit Kumar. Managing Partner and Global Head – Consulting Services. #### Omkar Nisal. #### Srikumar Rao. Managing Partner and Global Head – Engineering. #### Hari Shetty. Chief Strategist and Technology Officer. CEO, AI-Native Business & Platforms Unit. Managing Partner and Global Head – Consulting. View Profile Anne-Marie Rowland. #### Anne-Marie Rowland. #### Kanwar Singh. ## Contact Wipro.',
#    'score': 0.86954874,
#    'raw_content': None},
#   {'url': 'https://www.wipro.com/leadership/srini-pallia',
#    'title': 'Srini Pallia Leads Wipro Limited as CEO & MD',
#    'content': 'Srini Pallia | Chief Executive Officer and Managing Director. Srini Palliais the Chief Executive Officer and Managing Director of Wipro Limited. In his role as the CEO, Srini sets the vision and strategy for Wipro’s business and leads a team of global leaders to drive consistent execution of Wipro’s AI-powered, consulting- led approach across six continents. Prior to assuming the Global CEO role, Srini served as CEO of Wipro’s Americas 1 Strategic Market Unit (SMU), turning it into Wipro’s largest and fastest growing SMU. In his more than three decades at Wipro, Srini has held numerous leadership roles, including President of Wipro’s Consumer Business Unit and Global Head of Business Application Services. Srini holds a bachelor’s degree in engineering, and a master’s in management studies from Indian Institute of Science, Bangalore. He graduated from Harvard Business School’s Leading Global Businesses executive program, and the Advanced Leadership Program at McGill Executive Institute.',
#    'score': 0.86108357,
#    'raw_content': None},
#   {'url': 'https://www.linkedin.com/posts/srini-pallia_i-am-honored-and-humbled-to-assume-the-role-activity-7182579016489476096-tlsM',
#    'title': "Srini Pallia's Post",
#    'content': 'By clicking Continue to join or sign in, you agree to LinkedIn’s User Agreement, Privacy Policy, and Cookie Policy. Wipro appoints Srini Pallia as CEO and Managing Director. Srini has been with Wipro for over three decades and was most recently the CEO of Americas 1, Wipro’s largest and fastest growing market unit. Hearty Congratulations 🎉 Srini Pallia Have always been proud to be working under your leadership!! Congratulations Srini. Congratulations Srini !! Congratulations Srini. Congratulations Srini. Wishing you all the best and more success to Wipro! By clicking Continue to join or sign in, you agree to LinkedIn’s User Agreement, Privacy Policy, and Cookie Policy. By clicking Continue to join or sign in, you agree to LinkedIn’s User Agreement, Privacy Policy, and Cookie Policy.',
#    'score': 0.8524574,
#    'raw_content': None}],
#  'response_time': 0.0,
#  'request_id': '8a1825e4-01b6-4066-be6c-90b5517641a4'}

# %%
agent = create_agent(
    model="ollama:qwen2.5:3b",
    tools=[web_search]
)

question = HumanMessage(content="Who is the current mayor of San Francisco?")

response = agent.invoke(
    {"messages": [question]}
)

# %%
from pprint import pprint

pprint(response['messages'])
# Out:
# [HumanMessage(content='Who is the current mayor of San Francisco?', additional_kwargs={}, response_metadata={}, id='413b01f9-567b-4d1f-9ecb-7844a4dc08ce'),
#  AIMessage(content='', additional_kwargs={}, response_metadata={'model': 'qwen2.5:3b', 'created_at': '2026-07-12T17:22:01.095606Z', 'done': True, 'done_reason': 'stop', 'total_duration': 1153294417, 'load_duration': 150003209, 'prompt_eval_count': 152, 'prompt_eval_duration': 64430000, 'eval_count': 24, 'eval_duration': 906528000, 'logprobs': None, 'model_name': 'qwen2.5:3b', 'model_provider': 'ollama'}, id='lc_run--019f5759-a275-76c2-a8bc-05e2ebbf0eef-0', tool_calls=[{'name': 'web_search', 'args': {'query': 'current mayor of San Francisco'}, 'id': '2094071b-b6f9-4c05-a6f3-be10303986a7', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 152, 'output_tokens': 24, 'total_tokens': 176}),
#  ToolMessage(content='{"query": "current mayor of San Francisco", "follow_up_questions": null, "answer": null, "images": [], "results": [{"url": "https://en.wikipedia.org/wiki/Daniel_Lurie", "title": "Daniel Lurie - Wikipedia", "content": "# Daniel Lurie. | 46th Mayor of San Francisco |. **Daniel Lawrence Lurie** (born February 4, 1977) is an American politician and philanthropist who is the 46th and incumbent mayor of San Francisco, serving since 2025. He is the founder and former CEO of Tipping Point Community. Daniel Lawrence Lurie was born and raised in San Francisco, the son of Mimi (née\xa0Ruchwarger) and Rabbi Brian Lurie. Daniel is an heir to the Levi Strauss fortune through his stepfather, Peter, and is the first cousin once removed of outgoing New York congressman Dan Goldman, another member of the Levi Strauss family. In 2003 he returned to the Bay Area, earning a Master of Public Policy from the Goldman School of Public Policy at the University of California, Berkeley, in 2005; his thesis consisted of a business plan for a charitable foundation based on the Robin Hood model. On September 26, 2023, Lurie launched his candidacy for mayor of San Francisco in the 2024 election, challenging incumbent mayor London Breed.", "score": 0.8740022, "raw_content": null}, {"url": "https://apnews.com/article/san-francisco-new-mayor-liberal-city-81ea0a7b37af6cbb68aea7ef5cc6a4f0", "title": "San Francisco\'s new mayor is starting to unite the fractured city", "content": "Test Your News I.Q. 2026 Elections Election Results Election calendar White House Congress Supreme Court The latest AP-NORC polls. San Francisco Mayor Daniel Lurie, a political newcomer and Levi Strauss heir, has marked his first 100 days with a hands-on, business-friendly approach to tackling the city’s homelessness, drug crisis, and public safety concerns. San Francisco mayoral candidate Daniel Lurie, left, poses for a photo with Martin Damyan, who says he voted for Lurie, in San Francisco, Saturday, Oct. 26, 2024. Mayor-elect Daniel Lurie, center, speaks with people in the Tenderloin neighborhood Wednesday, Jan. 8, 2025, in San Francisco. San Francisco Mayor Daniel Lurie speaks at a rally of city leaders opposing President Trump\'s immigration crackdown on the steps of City Hall Tuesday, Jan. 28, 2025 in San Francisco. Lurie said criticism over the influence of tech and money in city politics “divided San Francisco in the past” and that this is a new San Francisco.", "score": 0.85538095, "raw_content": null}, {"url": "https://www.sf.gov/departments--office-mayor", "title": "Office of the Mayor", "content": "Image 1: San Francisco city sealSF.gov. Contact City departmentsfor help with services. ### Office of the Mayor\'s newsletter. Daniel Lurie is the 46th Mayor of the City and County of San Francisco. Image 2: Image of Mayor Daniel Lurie. ## Mayor Daniel Lurie. We are here to provide exceptional core city services that enable every San Franciscan to live safe, healthy and productive lives.Read about Mayor Lurie\'s priorities. ## Calendar. Office of the Mayor General Disclosures Find documents related to Ethics laws from the Office of the Mayor.Accessibility Statement for Office of the Mayor The Office of the Mayor wants everyone to be able to use this website easily.Office of the Mayor Executive Directives Find executives directives related to the Office of Mayor Daniel Lurie. ### Mayor. Image 3: Mayor Daniel LurieDaniel Lurie Mayor. Submit requests for the Office of the Mayor. Image 4: City and County of San Francisco.", "score": 0.8170061, "raw_content": null}, {"url": "https://www.politico.com/news/magazine/2025/02/23/daniel-lurie-san-francisco-mayor-00205527", "title": "Mayor Lurie Tries to Bloomberg-ize San Francisco", "content": "Mayor Daniel Lurie (left) speaks to San Francisco Police Chief William Scott while walking through the Tenderloin neighborhood in San Francisco, on Jan. 8, 2025. **SAN FRANCISCO —** Daniel Lurie began the morning of his inaugurati ...
#  AIMessage(content="Based on the information found from my search, Daniel Lurie is currently serving as the 46th and incumbent mayor of San Francisco. He was born in San Francisco and became involved in politics by founding Tipping Point Community in 2005. Prior to running for mayor, he worked at Bill Bradley's presidential campaign and at Robin Hood in New York.\n\nIn his inauguration, Daniel Lurie started with a hands-on approach tackling the city's homelessness, drug crisis, and public safety concerns. He aims to bring more business-friendly measures to San Francisco while also uniting the city that has seen division due to tech influence and money in politics.", additional_kwargs={}, response_metadata={'model': 'qwen2.5:3b', 'created_at': '2026-07-12T17:22:13.792752Z', 'done': True, 'done_reason': 'stop', 'total_duration': 11828755958, 'load_duration': 155070125, 'prompt_eval_count': 1699, 'prompt_eval_duration': 6073835000, 'eval_count': 134, 'eval_duration': 5586733000, 'logprobs': None, 'model_name': 'qwen2.5:3b', 'model_provider': 'ollama'}, id='lc_run--019f5759-aa6a-79e1-be3a-f7383e9914d9-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 1699, 'output_tokens': 134, 'total_tokens': 1833})]
