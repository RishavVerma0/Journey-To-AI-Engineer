# %% [markdown]
# # Creating my personal chef

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from langchain.tools import tool
from typing import Dict, Any
from tavily import TavilyClient

tavily_client = TavilyClient()

@tool
def web_search(query: str) -> Dict[str, Any]:

    """Search the web for information"""

    return tavily_client.search(query)

# %%
system_prompt = """

You are a personal chef. The user will give you a list of ingredients they have left over in their house.

Using the web search tool, search the web for recipes that can be made with the ingredients they have.

Return recipe suggestions and eventually the recipe instructions to the user, if requested.

"""

# %%
from langchain.agents import create_agent
from langgraph.checkpoint.memory import InMemorySaver

agent = create_agent(
    model="ollama:qwen2.5:3b",
    tools=[web_search],
    system_prompt=system_prompt,
    checkpointer=InMemorySaver()
)

# %%
from langchain.messages import HumanMessage

config = {"configurable": {"thread_id": "1"}}

response = agent.invoke(
    {"messages": [HumanMessage(content="I have some leftover chicken and rice. What can I make?")]},
    config
)

print(response['messages'][-1].content)
# Out:
# Here are some recipes that you can make with chicken and rice:
#
# 1. [Chicken and Rice Casserole with Cream of Mushroom Soup](https://www.thekitchn.com/chicken-rice-dishes-23753036) - A comforting dish made from simple ingredients, perfect for feeling like home every single time.
#
# 2. One-Pot Chicken and Rice - This recipe combines the elements of risotto and soup into one meal that feeds a large family with minimal effort.
#
# 3. 15-Minute Chicken & Rice Dinner | Campbell's® Recipes - A quick and easy dish using ingredients you usually have on hand, perfect for weeknights.
#
# 4. Marry Me Chicken and Rice - This is an easy one-pan dinner that combines tender rice, juicy chicken with flavors of seasonings.
#
# 5. Mamaw’s Chicken and Rice Casserole Recipe - An effortless casserole recipe packed full of flavor and cheesy goodness.
#
# Would you like to see the instructions for any of these recipes?

# %%
from pprint import pprint

pprint(response)
# Out:
# {'messages': [HumanMessage(content='I have some leftover chicken and rice. What can I make?', additional_kwargs={}, response_metadata={}, id='095c3806-8a62-4baa-926c-6bf19e986638'),
#               AIMessage(content='', additional_kwargs={}, response_metadata={'model': 'qwen2.5:3b', 'created_at': '2026-07-12T18:27:35.626228Z', 'done': True, 'done_reason': 'stop', 'total_duration': 5994958125, 'load_duration': 4211101958, 'prompt_eval_count': 199, 'prompt_eval_duration': 842842000, 'eval_count': 24, 'eval_duration': 916761000, 'logprobs': None, 'model_name': 'qwen2.5:3b', 'model_provider': 'ollama'}, id='lc_run--019f5795-988a-7852-afe5-a6805f95ee28-0', tool_calls=[{'name': 'web_search', 'args': {'query': 'chicken and rice recipes'}, 'id': '7bcb7e05-1ba7-4d54-a251-a6e85ca89232', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 199, 'output_tokens': 24, 'total_tokens': 223}),
#               ToolMessage(content='{"query": "chicken and rice recipes", "follow_up_questions": null, "answer": null, "images": [], "results": [{"url": "https://www.thekitchn.com/chicken-rice-dishes-23753036", "title": "26 Comforting Chicken & Rice Dinner Ideas That Taste Just Like Grandma’s Cooking", "content": "I cover recipe content on The Kitchn, write and update recipes and recipe roundups, and test recipes for the team. Whether it’s baked into a creamy casserole or cooked together in one pot, it’s the kind of meal that feels like home every single time. Chicken and rice dishes are the ultimate comfort food, and they’re endlessly adaptable depending on what I have in the kitchen. Here you’ll find some of my favorite ways to make it — cozy casseroles like chicken and rice casserole with cream of mushroom soup and no-peek chicken casserole, plus easy one-pan dinners like French onion chicken and rice and Italian chicken and rice. I love that these recipes come together with just a few simple ingredients but still feel hearty and satisfying enough for a weeknight dinner. This chicken and rice casserole with cream of mushroom soup is one of those dishes that feels like a warm hug on a plate. Chicken and Rice Casserole with Cream of Mushroom Soup.", "score": 0.8790744, "raw_content": null}, {"url": "https://iowagirleats.com/one-pot-chicken-and-rice", "title": "One Pot Chicken and Rice - Family Favorite Recipe", "content": "Part risotto (without all the stirring) and part soup, this creamy chicken and rice recipe is simple, comforting, and made entirely in one pot with fridge and pantry staples. 1. **It’s easy.** Toss everything into a soup pot and let it simmer while you stir here and there. 3. **It’s wallet-friendly.** This is a greal meal to stretch a package of chicken breasts and feed a large family. ## What’s in Chicken and Rice? Raid the fridge and pantry for the everyday ingredients you’ll need to make this easy, one pot recipe. * **Butter.** To saute the carrots and add a bit of luxuriousness to the dish at the end. 1. **Can I use brown rice?** You can, but you will need to add more broth to the recipe, and simmer the rice longer. **Step 1:** Add**sliced or shredded carrots** to **melted butter** in a large soup pot over medium heat then season to taste with homemade seasoned salt and **pepper.** Place a lid on top then cook until the carrots are tender, 5-6 minutes, stirring occasionally.", "score": 0.87139857, "raw_content": null}, {"url": "https://www.campbells.com/recipes/15-minute-chicken-rice-dinner", "title": "15-Minute Chicken & Rice Dinner | Campbell\'s® Recipes", "content": "# 15-Minute Chicken & Rice Dinner. 15-Minute Chicken & Rice Dinner gives you chicken, rice and veggies, all in one skillet, all in 15 minutes, start to finish. It also uses ingredients you usually have on hand, so there\'s no need to make a late grocery run! Start by browning some chicken breasts, then add condensed cream of chicken soup, water, instant rice and broccoli to the skillet. This 15-Minute Chicken & Rice Dinner recipe is so quick and easy, no one will even have time to ask, What\'s for dinner? Add the chicken and cook for 6 minutes, turning once or until golden on both sides *(to prevent sticking- make sure the skillet and oil are hot before adding the chicken)*. Stir the soup, water and paprika in the skillet and\xa0heat to a boil. Stir in the rice and broccoli. #### Cream of Chicken Soup.", "score": 0.86303437, "raw_content": null}, {"url": "https://www.thecountrycook.net/marry-me-chicken-and-rice", "title": "Marry Me Chicken and Rice - The Country Cook", "content": "Home » Dinner Recipes » Marry Me Chicken and Rice. *Creamy, flavorful and cheesy, this Marry Me Chicken is **an easy one-pan dinner** that’s hearty with tender rice, juicy chicken and seasonings!*. Marry Me Chicken and Rice is a fantastic one pan meal that is inspired by all the Marry Me Chicken recipes! My Crock Pot Marry Me Chicken is one of the most popular r ...
#               AIMessage(content="Here are some recipes that you can make with chicken and rice:\n\n1. [Chicken and Rice Casserole with Cream of Mushroom Soup](https://www.thekitchn.com/chicken-rice-dishes-23753036) - A comforting dish made from simple ingredients, perfect for feeling like home every single time.\n   \n2. One-Pot Chicken and Rice - This recipe combines the elements of risotto and soup into one meal that feeds a large family with minimal effort.\n\n3. 15-Minute Chicken & Rice Dinner | Campbell's® Recipes - A quick and easy dish using ingredients you usually have on hand, perfect for weeknights.\n\n4. Marry Me Chicken and Rice - This is an easy one-pan dinner that combines tender rice, juicy chicken with flavors of seasonings. \n\n5. Mamaw’s Chicken and Rice Casserole Recipe - An effortless casserole recipe packed full of flavor and cheesy goodness.\n\nWould you like to see the instructions for any of these recipes?", additional_kwargs={}, response_metadata={'model': 'qwen2.5:3b', 'created_at': '2026-07-12T18:27:53.022982Z', 'done': True, 'done_reason': 'stop', 'total_duration': 15210512958, 'load_duration': 155931375, 'prompt_eval_count': 1697, 'prompt_eval_duration': 6017541000, 'eval_count': 211, 'eval_duration': 9005967000, 'logprobs': None, 'model_name': 'qwen2.5:3b', 'model_provider': 'ollama'}, id='lc_run--019f5795-b8cf-7d53-8862-9b34d05b959b-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 1697, 'output_tokens': 211, 'total_tokens': 1908})]}
