# %% [markdown]
# # 1. Text input

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain.agents import create_agent
agent = create_agent(
    model="ollama:qwen2.5:3b",
    system_prompt="You are a automotive enthusiast with a great knowledge base about cars and bikes. Please respond to the user's request accordingly."
)

# %%
from langchain.messages import HumanMessage

question = HumanMessage(content=[{"type": "text", "text": "Provide me a list of cars offered by Maruti Suzuki in India"}])

response = agent.invoke(
    {"messages": [question]}
)

print(response['messages'][-1].content)
# Out:
# Maruti Suzuki offers a range of vehicles catering to different segments and needs in India. Here is an overview of some popular models from Maruti Suzuki:
#
# 1. Wagon R: Compact MPV (Multi-Purpose Vehicle)
# 2. Alto 800/1200/1500: Small hatchback
# 3. Vitara Brezza: SUV for the urban compact segment
# 4. Baleno: A stylish, compact sedan in the Maruti portfolio
# 5. Suzuki Ertiga: Mid-size MPV designed to meet family needs with space and comfort
# 6. Swift/Dzire: Sedans that cover all segments from small hatchbacks (Swift) to mid-sized sedans (Dzire)
# 7. Ciaz: A spacious sedan in the larger segment, also a part of Maruti Suzuki’s portfolio
# 8. S-Cross: An SUV targeting the luxury and premium vehicle space with its advanced features and design
#
# It's important to note that these models are subject to change based on current market demands and company strategies. Additionally, there might be other variants or special editions available in certain markets.

# %% [markdown]
# # Image Input

# %%
from ipywidgets import FileUpload
from IPython.display import display

uploader = FileUpload(accept='.png', multiple=False)
display(uploader)
# Out:
# FileUpload(value=(), accept='.png', description='Upload')

# %%
print(uploader.value)

# %%
import base64

# Get the first (and only) uploaded file dict
uploaded_file = uploader.value[0]

# This is a memoryview
content_mv = uploaded_file["content"]

# Convert memoryview -> bytes
img_bytes = bytes(content_mv)  # or content_mv.tobytes()

# Now base64 encode
img_b64 = base64.b64encode(img_bytes).decode("utf-8")

# %%
multimodal_question = HumanMessage(content=[
    {"type": "text", "text": "Tell me about this capital"},
    {"type": "image", "base64": img_b64, "mime_type": "image/png"}
])

response = agent.invoke(
    {"messages": [multimodal_question]}
)

print(response['messages'][-1].content)

# %% [markdown]
# # Audio input

# %%
import sounddevice as sd
from scipy.io.wavfile import write
import base64
import io
import time
from tqdm import tqdm

# Recording settings
duration = 5  # seconds
sample_rate = 44100

print("Recording...")
audio = sd.rec(int(duration * sample_rate), samplerate=sample_rate, channels=1)
# Progress bar for the duration
for _ in tqdm(range(duration * 10)):   # update 10× per second
    time.sleep(0.1)
sd.wait()
print("Done.")

# Write WAV to an in-memory buffer
buf = io.BytesIO()
write(buf, sample_rate, audio)
wav_bytes = buf.getvalue()

aud_b64 = base64.b64encode(wav_bytes).decode("utf-8")

# %%
agent = create_agent(
    model='gpt-audio',
)

multimodal_question = HumanMessage(content=[
    {"type": "text", "text": "Tell me about this audio file"},
    {"type": "audio", "base64": aud_b64, "mime_type": "audio/wav"}
])

response = agent.invoke(
    {"messages": [multimodal_question]}
)

print(response['messages'][-1].content)
