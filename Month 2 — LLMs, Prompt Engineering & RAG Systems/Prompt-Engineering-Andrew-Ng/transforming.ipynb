# %% [markdown]
# # Transforming
#
# In this notebook, we will explore how to use Large Language Models for text transformation tasks such as language translation, spelling and grammar checking, tone adjustment, and format conversion.
#
# ## Setup

# %%
from openai import OpenAI
import os
from dotenv import load_dotenv

load_dotenv()
model="llama-3.1-8b-instant"
client = OpenAI(
    api_key=os.environ["GROQ_API_KEY"],
    base_url="https://api.groq.com/openai/v1"
)

# %%
from openai import OpenAI
def get_completion(prompt, model="llama-3.1-8b-instant"):
    messages = [
        {"role": "system", "content": "You are a helpful assistant."},
        {"role": "user", "content": prompt}
    ]

    response = client.chat.completions.create(
        model=model,
        messages=messages,
        temperature=0
    )

    return response.choices[0].message.content

# %% [markdown]
# ## Translation
#
# ChatGPT is trained with sources in many languages. This gives the model the ability to do translation. Here are some examples of how to use this capability.

# %%
prompt = f"""
Translate the following English text to Spanish: \ 
```Hi, I would like to order a blender```
"""
response = get_completion(prompt)
print(response)
# Out:
# The translation of the English text to Spanish is:
#
# "Hola, me gustaría pedir un licuadora."

# %%
prompt = f"""
Tell me which language this is: 
```Combien coûte le lampadaire?```
"""
response = get_completion(prompt)
print(response)
# Out:
# The language is French.

# %%
prompt = f"""
Translate the following  text to French and Spanish
and English pirate: \
```I want to order a basketball```
"""
response = get_completion(prompt)
print(response)
# Out:
# Here are the translations:
#
# - **English:** I want to order a basketball.
# - **French:** Je veux commander un panier de basket.
# - **Spanish:** Quiero pedir un balón de baloncesto.
#
# Note: In French, "panier de basket" is a more common translation for "basketball" as it directly translates to "basketball basket".

# %%
prompt = f"""
Translate the following text to Spanish in both the \
formal and informal forms: 
'Would you like to order a pillow?'
"""
response = get_completion(prompt)
print(response)
# Out:
# Here are the translations in both formal and informal forms:
#
# **Formal:**
# - 'Would you like to order a pillow?'
#   - Formal: ¿Le gustaría pedir un cojín? (This is the most formal way to ask, using the formal 'you' (usted) and the verb 'gustaría' to express a polite question.)
#   - Alternative formal: ¿Desea pedir un cojín? (This is another way to ask, using the verb 'desea' to express a desire or preference.)
#
# **Informal:**
# - 'Would you like to order a pillow?'
#   - Informal: ¿Quieres pedir un cojín? (This is the most common way to ask in informal settings, using the informal 'you' (tú) and the verb 'quieres' to express a desire or preference.)
#   - Alternative informal: ¿Te gustaría un cojín? (This is another way to ask, using the verb 'gustaría' to express a polite question, but in an informal setting.)

# %% [markdown]
# ### Universal Translator
# Imagine you are in charge of IT at a large multinational e-commerce company. Users are messaging you with IT issues in all their native languages. Your staff is from all over the world and speaks only their native languages. You need a universal translator!

# %%
user_messages = [
  "La performance du système est plus lente que d'habitude.",  # System performance is slower than normal         
  "Mi monitor tiene píxeles que no se iluminan.",              # My monitor has pixels that are not lighting
  "Il mio mouse non funziona",                                 # My mouse is not working
  "Mój klawisz Ctrl jest zepsuty",                             # My keyboard has a broken control key
  "我的屏幕在闪烁"                                               # My screen is flashing
]

# %%
for issue in user_messages:
    prompt = f"Tell me what language this is: ```{issue}```"
    lang = get_completion(prompt)
    print(f"Original message ({lang}): {issue}")

    prompt = f"""
    Translate the following  text to English \
    and Korean: ```{issue}```
    """
    response = get_completion(prompt)
    print(response, "\n")
# Out:
# Original message (This is French.): La performance du système est plus lente que d'habitude.
# **English Translation:**
# The system's performance is slower than usual.
#
# **Korean Translation:**
# 시스템의 성능이 평소보다 느립니다.
#
# Original message (The language is Spanish.): Mi monitor tiene píxeles que no se iluminan.
# The translation of the text to English is:
#
# "My monitor has pixels that don't light up."
#
# And the translation to Korean is:
#
# "나의 모니터는 불이 들어오지 않는 픽셀들이 있습니다."
#
# Original message (The language is Italian.): Il mio mouse non funziona
# The translation of the text to English is:
#
# "My mouse is not working."
#
# And the translation to Korean is:
#
# "마우스가 작동하지 않습니다."
#
# Original message (The language is Polish.): Mój klawisz Ctrl jest zepsuty
# The translation of the text to English is:
#
# "My Ctrl key is broken."
#
# And the translation to Korean is:
#
# "내 Ctrl 키가 고장났습니다."
#
# Original message (The language is Chinese.): 我的屏幕在闪烁
# The translation of the text to English is:
#
# "My screen is flickering."
#
# And the translation to Korean is:
#
# "나의 화면이 깜빡이는 중입니다."
